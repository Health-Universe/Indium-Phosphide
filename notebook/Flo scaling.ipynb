# %%
import numpy as np
import pandas as pd
import os
import joblib
import sklearn
from sklearn.svm import SVR
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
df = pd.read_csv('../dataset/flo/Flo_dataset.csv')
df
# Out:
#                 in_source  in_amount_mmol                       p_source  \
# 0          indium acetate            1.00  tris(trimethylsilyl)phosphine
# 1    chloroindium oxalate            1.05  tris(trimethylsilyl)phosphine
# 2         indium chloride            0.30               white phosphorus
# 3         indium chloride            0.30               white phosphorus
# 4          indium acetate            1.00  tris(trimethylsilyl)phosphine
# ..                    ...             ...                            ...
# 241        indium acetate            1.00  tris(trimethylsilyl)phosphine
# 242       indium chloride           10.00               sodium phosphide
# 243        indium acetate            4.00  tris(trimethylsilyl)phosphine
# 244        indium acetate            4.00  tris(trimethylsilyl)phosphine
# 245        indium acetate            4.00  tris(trimethylsilyl)phosphine
#
#      p_amount_mmol  ligand_source  ligand_amount_mmol  \
# 0            1.000  dodecanethiol                 0.5
# 1            1.400           None                 0.0
# 2            0.450           None                 0.0
# 3            0.450           None                 0.0
# 4            1.000  dodecanethiol                 0.5
# ..             ...            ...                 ...
# 241          0.499  myristic acid                 3.0
# 242         11.300           None                 0.0
# 243          2.000  palmitic acid                12.0
# 244          2.000  palmitic acid                12.0
# 245          2.000  palmitic acid                12.0
#
#                    first_sol  first_sol_amount_ml         second_sol  \
# 0                       None             0.000000               None
# 1    trioctylphosphine oxide             0.222222               None
# 2                 oleylamine             0.264000               None
# 3                 oleylamine             0.264000               None
# 4                 octadecene             1.000000               None
# ..                       ...                  ...                ...
# 241               octadecene            75.000000               None
# 242        dimethylformamide            90.000000               None
# 243               octadecene           100.000000  trioctylphosphine
# 244               octadecene           100.000000  trioctylphosphine
# 245               octadecene           100.000000  trioctylphosphine
#
#      second_sol_amount_ml  ...         other_1  other_1_amount_mmol other_2  \
# 0                     0.0  ...   zinc stearate                 2.00    None
# 1                     0.0  ...            None                 0.00    None
# 2                     0.0  ...   zinc chloride                 1.47    None
# 3                     0.0  ...   zinc chloride                 1.47    None
# 4                     0.0  ...  zinc octanoate                 2.00    None
# ..                    ...  ...             ...                  ...     ...
# 241                   0.0  ...            None                 0.00    None
# 242                   0.0  ...            None                 0.00    None
# 243                  10.0  ...            None                 0.00    None
# 244                  10.0  ...            None                 0.00    None
# 245                  10.0  ...            None                 0.00    None
#
#      other_2_amount_mmol total_volume_ml  temp_c  time_min  diameter_nm  \
# 0                    0.0           0.120     300      30.0         None
# 1                    0.0           0.223     270    4320.0         2.61
# 2                    0.0           0.264     180      30.0         None
# 3                    0.0           0.264     210      30.0         None
# 4                    0.0           1.120     180      60.0         None
# ..                   ...             ...     ...       ...          ...
# 241                  0.0          75.000     270     180.0            4
# 242                  0.0          90.000     160     120.0         None
# 243                  0.0         110.000     260       1.0         None
# 244                  0.0         110.000     260      20.0         None
# 245                  0.0         110.000     260      40.0          2.7
#
#      abs_nm emission_nm
# 0       539         480
# 1       610        None
# 2       560         595
# 3       590         635
# 4      None         500
# ..      ...         ...
# 241     585         630
# 242     465         550
# 243     465        None
# 244     495        None
# 245     500        None
#
# [246 rows x 22 columns]

# %%
#Checks if there are any columns with no values
df.isna().sum()
# Out:
# in_source               0
# in_amount_mmol          0
# p_source                0
# p_amount_mmol           0
# ligand_source           0
# ligand_amount_mmol      0
# first_sol               0
# first_sol_amount_ml     0
# second_sol              0
# second_sol_amount_ml    0
# third_sol               0
# third_sol_amount_ml     0
# other_1                 0
# other_1_amount_mmol     0
# other_2                 0
# other_2_amount_mmol     0
# total_volume_ml         0
# temp_c                  0
# time_min                0
# diameter_nm             0
# abs_nm                  0
# emission_nm             0
# dtype: int64
